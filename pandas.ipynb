# %% [markdown]
# <a href="https://colab.research.google.com/github/LuigiFerrari14/Python/blob/main/pandas.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #inicio

# %%
# !pip install pandas
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...

# %% [markdown]
# python and
#
# pandas &

# %%
import pandas as pd
import numpy as np
pd.__version__
# Out:
# '1.3.5'

# %% [markdown]
# Serie

# %%
ex1 = pd.Series(['valor 1','valor 2', 'valor 3'], index=(1,2,3), name='Primeira Serie')
ex2 = pd.Series(['valor 1','valor 2', 'valor 3'], index=(1,2,3), name='Segunda Serie')

# %% [markdown]
# DataFrame

# %%
pd.DataFrame([ex1,ex2])
# Out:
#                       1        2        3
# Primeira Serie  valor 1  valor 2  valor 3
# Segunda Serie   valor 1  valor 2  valor 3

# %%
municipio = pd.read_csv("/content/drive/MyDrive/municipios.csv", sep=',')

# %%
municipio
# Out:
#       codigo_ibge                 nome  latitude  longitude  capital  \
# 0         5200050      Abadia de Goiás -16.75730   -49.4412        0
# 1         3100104  Abadia dos Dourados -18.48310   -47.3916        0
# 2         5200100            Abadiânia -16.19700   -48.7057        0
# 3         3100203               Abaeté -19.15510   -45.4444        0
# 4         1500107           Abaetetuba  -1.72183   -48.8788        0
# ...           ...                  ...       ...        ...      ...
# 5565      2933604          Xique-Xique -10.82300   -42.7245        0
# 5566      2517407               Zabelê  -8.07901   -37.1057        0
# 5567      3557154             Zacarias -21.05060   -50.0552        0
# 5568      2114007              Zé Doca  -3.27014   -45.6553        0
# 5569      4219853               Zortéa -27.45210   -51.5520        0
#
#       codigo_uf
# 0            52
# 1            31
# 2            52
# 3            31
# 4            15
# ...         ...
# ...

# %%
municipio[:3]
# Out:
#    codigo_ibge                 nome  latitude  longitude  capital  codigo_uf
# 0      5200050      Abadia de Goiás  -16.7573   -49.4412        0         52
# 1      3100104  Abadia dos Dourados  -18.4831   -47.3916        0         31
# 2      5200100            Abadiânia  -16.1970   -48.7057        0         52

# %%
#gerar para baixar
#municipio.to_csv("Municipio.csv")

# %%
#primeiros 5
municipio.head()
# Out:
#    codigo_ibge                 nome  latitude  longitude  capital  codigo_uf
# 0      5200050      Abadia de Goiás -16.75730   -49.4412        0         52
# 1      3100104  Abadia dos Dourados -18.48310   -47.3916        0         31
# 2      5200100            Abadiânia -16.19700   -48.7057        0         52
# 3      3100203               Abaeté -19.15510   -45.4444        0         31
# 4      1500107           Abaetetuba  -1.72183   -48.8788        0         15

# %%
#ultimos 5
municipio.tail()
# Out:
#       codigo_ibge         nome  latitude  longitude  capital  codigo_uf
# 5565      2933604  Xique-Xique -10.82300   -42.7245        0         29
# 5566      2517407       Zabelê  -8.07901   -37.1057        0         25
# 5567      3557154     Zacarias -21.05060   -50.0552        0         35
# 5568      2114007      Zé Doca  -3.27014   -45.6553        0         21
# 5569      4219853       Zortéa -27.45210   -51.5520        0         42

# %%
#descricao do index
municipio.index

#ver colunas
municipio.columns
# Out:
# Index(['codigo_ibge', 'nome', 'latitude', 'longitude', 'capital', 'codigo_uf'], dtype='object')

# %%
#estatisticas descritivas
municipio.describe()
# Out:
#         codigo_ibge     latitude    longitude      capital    codigo_uf
# count  5.570000e+03  5570.000000  5570.000000  5570.000000  5570.000000
# mean   3.253591e+06   -16.449144   -46.231003     0.004847    32.377738
# std    9.849103e+05     8.287237     6.408539     0.069461     9.833862
# min    1.100015e+06   -33.686600   -72.899700     0.000000    11.000000
# 25%    2.512126e+06   -22.843875   -50.878525     0.000000    25.000000
# 50%    3.146280e+06   -18.094300   -46.523200     0.000000    31.000000
# 75%    4.119190e+06    -8.496445   -41.410775     0.000000    41.000000
# max    5.300108e+06     4.603140   -32.410700     1.000000    53.000000

# %%
#transpor os dados, inverter linhas por colunas
municipio.T
# Out:
#                         0                    1          2        3     \
# codigo_ibge          5200050              3100104    5200100  3100203
# nome         Abadia de Goiás  Abadia dos Dourados  Abadiânia   Abaeté
# latitude            -16.7573             -18.4831    -16.197 -19.1551
# longitude           -49.4412             -47.3916   -48.7057 -45.4444
# capital                    0                    0          0        0
# codigo_uf                 52                   31         52       31
#
#                    4        5        6        7        8              9     \
# codigo_ibge     1500107  2300101  2900108  2900207  4100103        4200051
# nome         Abaetetuba  Abaiara   Abaíra    Abaré   Abatiá  Abdon Batista
# latitude       -1.72183 -7.34588 -13.2488 -8.72073 -23.3049       -27.6126
# longitude      -48.8788 -39.0416 -41.6619 -39.1162 -50.3133       -51.0233
# capital               0        0        0        0        0              0
# ...

# %%
municipio["nome"]
# Out:
# 0           Abadia de Goiás
# 1       Abadia dos Dourados
# 2                 Abadiânia
# 3                    Abaeté
# 4                Abaetetuba
#                ...
# 5565            Xique-Xique
# 5566                 Zabelê
# 5567               Zacarias
# 5568                Zé Doca
# 5569                 Zortéa
# Name: nome, Length: 5570, dtype: object

# %%
#posicao + nome - LOC
municipio.loc[0:5,["nome", "codigo_uf"]]
# Out:
#                   nome  codigo_uf
# 0      Abadia de Goiás         52
# 1  Abadia dos Dourados         31
# 2            Abadiânia         52
# 3               Abaeté         31
# 4           Abaetetuba         15
# 5              Abaiara         23

# %%
#valores da posicao (linha x) - ILOC
municipio.iloc[0]
# Out:
# codigo_ibge            5200050
# nome           Abadia de Goiás
# latitude              -16.7573
# longitude             -49.4412
# capital                      0
# codigo_uf                   52
# Name: 0, dtype: object

# %%
#posicoes(linha) x a y, das tabelas(colunas) x a y
municipio.iloc[:,2:4]
# Out:
#       latitude  longitude
# 0    -16.75730   -49.4412
# 1    -18.48310   -47.3916
# 2    -16.19700   -48.7057
# 3    -19.15510   -45.4444
# 4     -1.72183   -48.8788
# ...        ...        ...
# 5565 -10.82300   -42.7245
# 5566  -8.07901   -37.1057
# 5567 -21.05060   -50.0552
# 5568  -3.27014   -45.6553
# 5569 -27.45210   -51.5520
#
# [5570 rows x 2 columns]

# %%
municipio[municipio['codigo_uf'] == 14]
# Out:
#       codigo_ibge                nome  latitude  longitude  capital  codigo_uf
# 141       1400050         Alto Alegre  2.988580   -61.3072        0         14
# 184       1400027             Amajari  3.645710   -61.3692        0         14
# 642       1400100           Boa Vista  2.823840   -60.6753        1         14
# 707       1400159              Bonfim  3.361610   -59.8333        0         14
# 1038      1400175               Cantá  2.609940   -60.6058        0         14
# 1086      1400209           Caracaraí  1.827660   -61.1304        0         14
# 1145      1400233             Caroebe  0.884203   -59.6959        0         14
# 2256      1400282             Iracema  2.183050   -61.0415        0         14
# 3202      1400308             Mucajaí  2.439980   -60.9096        0         14
# 3276      1400407           Normandia  3.885300   -59.6204        0         14
# 3498      1400456           Pacaraima  4.479900   -61.1477        0         14
# ...

# %%
municipio[(municipio['codigo_uf'] > 51) & (municipio['codigo_uf'] < 53)]
# Out:
#       codigo_ibge                nome  latitude  longitude  capital  codigo_uf
# 0         5200050     Abadia de Goiás  -16.7573   -49.4412        0         52
# 2         5200100           Abadiânia  -16.1970   -48.7057        0         52
# 27        5200134             Acreúna  -17.3960   -50.3749        0         52
# 31        5200159           Adelândia  -16.4127   -50.1657        0         52
# 57        5200175  Água Fria de Goiás  -14.9778   -47.7823        0         52
# ...           ...                 ...       ...        ...      ...        ...
# 5441      5221908              Varjão  -17.0471   -49.6312        0         52
# 5488      5222005          Vianópolis  -16.7405   -48.5159        0         52
# 5492      5222054      Vicentinópolis  -17.7322   -49.8047        0         52
# 5504      5222203            Vila Boa  -15.0387   -47.0520        0         52
# 5513      5222302       Vila Propício  -15.4542   -48.8819        0         52
#
# [246 rows x 6 columns]

# %%
municipio['latitude'].mean()
# Out:
# -16.449143712746856

# %%
municipio['codigo_uf'].value_counts()
# Out:
# 31    853
# 35    645
# 43    497
# 29    417
# 41    399
# 42    295
# 52    246
# 22    224
# 25    223
# 21    217
# 26    185
# 23    184
# 24    167
# 15    144
# 51    141
# 17    139
# 27    102
# 33     92
# 50     79
# 32     78
# 28     75
# 13     62
# 11     52
# 12     22
# 16     16
# 14     15
# 53      1
# Name: codigo_uf, dtype: int64

# %%
#percentual dentre os dados -NORMALIZE=TRUE
municipio['codigo_uf'].value_counts(normalize=True)
# Out:
# 31    0.153142
# 35    0.115799
# 43    0.089228
# 29    0.074865
# 41    0.071634
# 42    0.052962
# 52    0.044165
# 22    0.040215
# 25    0.040036
# 21    0.038959
# 26    0.033214
# 23    0.033034
# 24    0.029982
# 15    0.025853
# 51    0.025314
# 17    0.024955
# 27    0.018312
# 33    0.016517
# 50    0.014183
# 32    0.014004
# 28    0.013465
# 13    0.011131
# 11    0.009336
# 12    0.003950
# 16    0.002873
# 14    0.002693
# 53    0.000180
# Name: codigo_uf, dtype: float64

# %%
municipio[["codigo_uf", "latitude"]].apply(lambda x: x.max())
# Out:
# codigo_uf    53.00000
# latitude      4.60314
# dtype: float64

# %%
municipio["codigo_uf"].sort_values()
# Out:
# 3406    11
# 4627    11
# 1428    11
# 4039    11
# 5193    11
#         ..
# 2212    52
# 2218    52
# 2235    52
# 2033    52
# 755     53
# Name: codigo_uf, Length: 5570, dtype: int64

# %%
#ordernar toda coluna pela tabela x  -BY
municipio.sort_values(by="codigo_uf")
# Out:
#       codigo_ibge                     nome  latitude  longitude  capital  \
# 3406      1100502  Novo Horizonte do Oeste  -11.6961   -61.9951        0
# 4627      1101484       São Felipe D'Oeste  -11.9023   -61.5026        0
# 1428      1100072               Corumbiara  -12.9551   -60.8947        0
# 4039      1101476    Primavera de Rondônia  -11.8295   -61.3153        0
# 5193      1101559            Teixeirópolis  -10.9056   -62.2420        0
# ...           ...                      ...       ...        ...      ...
# 2212      5210000                  Inhumas  -16.3611   -49.5001        0
# 2218      5210109                  Ipameri  -17.7215   -48.1581        0
# 2235      5210158        Ipiranga de Goiás  -15.1689   -49.6695        0
# 2033      5209457                 Guarinos  -14.7292   -49.7006        0
# 755       5300108                 Brasília  -15.7795   -47.9297        1
#
#       codigo_uf
# 3406         11
# 4627         11
# 1428         11
# 4039         11
# ...

# %% [markdown]
# #GRAFICOS

# %% [markdown]
# GRAFICOS - https://pandas.pydata.org/pandas-docs/stable/user_guide/visualization.html#visualization

# %%
import matplotlib.pyplot as plt

month_number = [1, 2, 3, 4, 5, 6, 7]
new_cases = [9926, 76246, 681488, 2336640,
             2835147, 4226655, 6942042]
#ADICIONAR OS DADOS NO PL.PLOT()
plt.plot(month_number, new_cases)
#exibir valor sem notação cientifica
plt.ticklabel_format(axis='y', style='plain')
#adicionar um titulo
plt.title('Mortes por mês | COVID 19')
#adicionar label em x e y
plt.xlabel('Mês')
plt.ylabel('Mortes')
#EXIBIR
plt.show()

# %% [markdown]
# -

# %% [markdown]
# Serie temporal

# %%
#transformar objeto em data
#df['Date_reported'] = pd.to_datetime(df['Date_reported'])

# %% [markdown]
# ![Captura de tela 2022-07-14 175925.png](data:image/png;base64,...)

# %% [markdown]
# DUAS LINHAS NO MSM GRAFICO
#
# LABEL PARA DIFERENCIAR A LINHA, TER UMA LEGENDA

# %%
plt.plot(france['Date_reported'], france['Cumulative_cases'],
         label='France')
plt.plot(uk['Date_reported'], uk['Cumulative_cases'],
         label='The UK')
plt.legend()
plt.show()

# %% [markdown]
# CASO A XLABEL ESTEJA SE SOBREPONDO UMA AS OURTAS PODEMOS MUDAR A ROTACAO

# %%
plt.xticks(rotation=45)

# %%
import matplotlib.pyplot as plt
month_number = [1, 2, 3, 4, 5, 6, 7]
new_cases = [9926, 76246, 681488, 2336640,
             2835147, 4226655, 6942042]
#ADICIONAR OS DADOS NO PL.PLOT()
plt.plot(month_number, new_cases)
#exibir valor sem notação cientifica
plt.ticklabel_format(axis='y', style='plain')
#adicionar um titulo
plt.title('Mortes por mês | COVID 19')
#adicionar label em x e y
plt.xlabel('Mês')
plt.ylabel('Mortes')


#########AQUI#################
plt.xticks(rotation=45)
###############################


#EXIBIR
plt.show()

# %% [markdown]
# -

# %% [markdown]
# gráfico de dispersão

# %%
plt.scatter()

# %%
traffic.plot.scatter(x='Slowness in traffic (%)',
                     y='Lack of electricity')
plt.show()

# %% [markdown]
# ![2.png](data:image/png;base64,...)

# %% [markdown]
# ![3.png](data:image/png;base64,...)

# %% [markdown]
# Podemos medir o quão bem os pontos se encaixam em uma linha reta usando o coeficiente de correlação de Pearson — também conhecido como r de Pearson .
#
# Os valores de r de Pearson estão entre -1,00 e +1,00. Quando a correlação
#
# positiva é perfeita, o r de Pearson é igual a +1,00. Quando a correlação
#
# negativa é perfeita, o r de Pearson é igual a -1,00. Um valor de 0,0 não mostra correlação.

# %% [markdown]
# ![4.png](data:image/png;base64,...)

# %% [markdown]
# COMO MEDIR O R DE PEARSON

# %% [markdown]
# O Series.corr()método só permite calcular a correlação entre duas colunas numéricas. Podemos obter uma visão geral das correlações usando o DataFrame.corr()método , que calcula o r de Pearson entre todos os pares de colunas numéricas.

# %% [markdown]
# .corr --- não importa a ordem para calcular o r de pearson

# %%
bike_sharing['temp'].corr(bike_sharing['cnt'])
#ou
bike_sharing['cnt'].corr(bike_sharing['temp'])

# %%
#fazer as relacoes entre todo df
bike_sharing.corr()

#escolher as tabelas
bike_sharing.corr()[['cnt', 'casual', 'registered']]

# %% [markdown]
# -

# %% [markdown]
# GRAFICO BARRAS

# %%
#SUBSTITUIR OS TICKS 0,1 PELO DIA DA SEMANA
plt.bar(weekday_averages['weekday'], weekday_averages['casual'])
plt.xticks(ticks=[0, 1, 2, 3, 4, 5, 6],
          labels=['Sunday', 'Monday', 'Tuesday', 'Wednesday',
                 'Thursday', 'Friday', 'Saturday'])
plt.show()

# %% [markdown]
# NA HORIZONTAL

# %%
plt.barh(weekday_averages['weekday'], weekday_averages['casual'])
plt.yticks(ticks=[0, 1, 2, 3, 4, 5, 6],
          labels=['Sunday', 'Monday', 'Tuesday', 'Wednesday',
                 'Thursday', 'Friday', 'Saturday'])
plt.show()

# %% [markdown]
# bins=comprimeiro

# %%
bike_sharing['cnt'].value_counts(bins=10).sort_index()

# %%
bike_sharing['cnt'].value_counts(bins=10)

(4368.0, 5237.2]    137
(3498.8, 4368.0]    122
(5237.2, 6106.4]     81
(6975.6, 7844.8]     79
(6106.4, 6975.6]     76
(2629.6, 3498.8]     73
(1760.4, 2629.6]     71
(891.2, 1760.4]      62
(7844.8, 8714.0]     17
(13.307, 891.2]      13
Name: cnt, dtype: int64

# %% [markdown]
# ![5.png](data:image/png;base64,...)

# %% [markdown]
# -

# %% [markdown]
# Os histogramas são um dos gráficos mais comuns que usamos na visualização exploratória de dados.
#
# Frequencia fica no y e oq vc quer saber no x

# %%
plt.hist(bike_sharing['cnt'])
plt.show()

# %% [markdown]
# ou

# %%
traffic['Slowness in traffic (%)'].plot.hist()
plt.show()

# %% [markdown]
# DROP COLUMNS

# %%
slowness_20_or_more.drop(['Slowness in traffic (%)','Hour (Coded)'],axis=1)

# %% [markdown]
# -

# %%
days = ['Monday', 'Tuesday', 'Wednesday', 'Thursday', 'Friday']
traffic_per_day = {}
for i, day in zip(range(0, 135, 27), days):
    each_day_traffic = traffic[i:i+27]
    traffic_per_day[day] = each_day_traffic

# %% [markdown]
# Usamos a zip()função acima para iterar sobre range()e daysao mesmo tempo.

# %%
traffic_per_day['Monday'].plot.line(x='Hour (Coded)',
                                    y='Slowness in traffic (%)')
plt.show()

# %% [markdown]
# Crie um gráfico de linha separado para cada dia usando um forloop. Repita a dayslista e, para cada dia, faça o seguinte:
#
# Plote um gráfico de linha usando o DataFrame.plot.line()método — Hour (Coded)deve estar no eixo x e Slowness in traffic (%)no eixo y.
#
# Adicione um título ao gráfico usando o nome do dia.
#
# Use plt.ylim([0, 25])para tornar o intervalo do eixo y igual para todos os gráficos — isso ajuda na comparação.
#
# Feche e exiba cada gráfico com plt.show().
#
# Inspecione e compare os gráficos – você percebe algum padrão recorrente em como a lentidão do tráfego muda durante o dia?

# %%
import pandas as pd
import matplotlib.pyplot as plt

traffic = pd.read_csv('traffic_sao_paulo.csv', sep=';')
traffic['Slowness in traffic (%)'] = traffic['Slowness in traffic (%)'].str.replace(',', '.')
traffic['Slowness in traffic (%)'] = traffic['Slowness in traffic (%)'].astype(float)

days = ['Monday', 'Tuesday', 'Wednesday', 'Thursday', 'Friday']
traffic_per_day = {}
#0 até o total de linhas pulando de 27 a 27(cada dia)
for i, day in zip(range(0, 135, 27), days):
    each_day_traffic = traffic[i:i+27]
    traffic_per_day[day] = each_day_traffic
    traffic_per_day[day].plot.line(x='Hour (Coded)',
                                   y='Slowness in traffic (%)')
    plt.title(day)
    #Use plt.ylim([0, 25])para tornar o intervalo do eixo y igual para todos os gráficos — isso ajuda na comparação.
    plt.ylim([0,25])
    plt.show()

# %%
#todos na msm tela
import pandas as pd
import matplotlib.pyplot as plt

traffic = pd.read_csv('traffic_sao_paulo.csv', sep=';')
traffic['Slowness in traffic (%)'] = traffic['Slowness in traffic (%)'].str.replace(',', '.')
traffic['Slowness in traffic (%)'] = traffic['Slowness in traffic (%)'].astype(float)

days = ['Monday', 'Tuesday', 'Wednesday', 'Thursday', 'Friday']
traffic_per_day = {}
for i, day in zip(range(0, 135, 27), days):
    each_day_traffic = traffic[i:i+27]
    traffic_per_day[day] = each_day_traffic

for day in days:
    plt.plot(traffic_per_day[day]['Hour (Coded)'],
             traffic_per_day[day]['Slowness in traffic (%)'],
             label=day)

plt.legend()
plt.show()

# %% [markdown]
# =

# %% [markdown]
# GRAFICO DE GRADE

# %% [markdown]
# Podemos especificar o número de linhas e colunas para nosso gráfico de grade usando a plt.subplot(nrows, ncols, index)função. Por exemplo, plt.subplot(3, 2, 1)significa que queremos construir o gráfico com índice 1em um gráfico de grade que possui 3linhas e 2colunas.

# %%
plt.figure()
plt.subplot(3, 2, 1)
plt.subplot(3, 2, 6) # index number 6
plt.show()

# %% [markdown]
# Os gráficos estão sobrepostos e o gráfico de grade como um todo parece um pouco cheio demais. Para corrigir isso, vamos aumentar o tamanho da figura inteira usando plt.figure(figsize=(width, height)).

# %%
import pandas as pd
import matplotlib.pyplot as plt

traffic = pd.read_csv('traffic_sao_paulo.csv', sep=';')
traffic['Slowness in traffic (%)'] = traffic['Slowness in traffic (%)'].str.replace(',', '.')
traffic['Slowness in traffic (%)'] = traffic['Slowness in traffic (%)'].astype(float)

days = ['Monday', 'Tuesday', 'Wednesday', 'Thursday', 'Friday']
traffic_per_day = {}
for i, day in zip(range(0, 135, 27), days):
    each_day_traffic = traffic[i:i+27]
    traffic_per_day[day] = each_day_traffic
    
#começar com o figure
plt.figure(figsize=(10,12))

for i, day in zip(range(1,6), days):
    plt.subplot(3, 2, i)
    plt.plot(traffic_per_day[day]['Hour (Coded)'],
        traffic_per_day[day]['Slowness in traffic (%)'])
    plt.title(day)
    plt.ylim([0,25])
    
plt.show()

# %% [markdown]
# ![6.png](data:image/png;base64,...)

# %%
municipio['codigo_uf'].plot(kind='hist')

# %%
municipio['codigo_uf'].value_counts().plot(kind='bar')

# %% [markdown]
# Agrupamento

# %%
municipio.groupby(['codigo_uf']).mean()#['nome da coluna']

# %% [markdown]
# valroes ausentes

# %%
municipio[municipio.capital.isnull() == False]

# %% [markdown]
# #Seaborn

# %%
import seaborn as sns
import matplotlib.pyplot as plt

#chamar o tema do sns
sns.set_theme()
sns.relplot(data=housing, x='Gr Liv Area', y='SalePrice')
plt.show()

# %% [markdown]
# terceiro parametro
#
# hue='Overall Qual'
#
# cor dos marcadores do grafico

# %%
sns.relplot(data=housing, x='Gr Liv Area', y='SalePrice',
            hue='Overall Qual')
plt.show()

# %% [markdown]
# palheta de cores
#
# quarto parametro cor

# %%
sns.relplot(data=housing, x='Gr Liv Area', y='SalePrice',
            hue='Overall Qual', palette='RdYlGn')
plt.show()
#red yellow green

# %% [markdown]
# quinto parametro
#
# size

# %% [markdown]
# Para tornar as diferenças de tamanho mais visíveis, aumentaremos o intervalo de tamanho — o sizesparâmetro aceita uma tupleespecificação do tamanho mínimo e máximo.

# %%
sns.relplot(data=housing, x='Gr Liv Area', y='SalePrice',
            hue='Overall Qual', palette='RdYlGn',
                        #so numero ( valor minimo da variavel, valor maximo da variavel)
            size='Garage Area', sizes=(1,300))
plt.show()

# %% [markdown]
# sexto parametro
#
# formas
#
# style

# %%
sns.relplot(data=housing, x='Gr Liv Area', y='SalePrice',
            hue='Overall Qual', palette='RdYlGn',
            size='Garage Area', sizes=(1,300),
                          #opcional
            style='Rooms', markers=['*','v'])
plt.show()

# %% [markdown]
# separar o grafico em dois a partir do ano(por exemplo)

# %% [markdown]
# col

# %%
sns.relplot(data=housing, x='Gr Liv Area', y='SalePrice',
            hue='Overall Qual', palette='RdYlGn',
            size='Garage Area', sizes=(1,300),
            style='Rooms', col='Year')
plt.show()

# %% [markdown]
# ![7.png](data:image/png;base64,...)

# %% [markdown]
# https://matplotlib.org/stable/tutorials/colors/colormaps.html

# %% [markdown]
# #Estilos Matplotlib

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import matplotlib.style as style

# %%
lst = [[1,0],[2,0],[3,77],[4,1844],[5,1448],[6,785],[7,769],[8,1020],[9,739],[10,751],[11,1225],[12,2247]]
death_toll = pd.DataFrame(lst, columns = [['Month', 'New_deaths']])

# %% [markdown]
# Criar o estilo ------ style.use('nome')

# %%
#chamar o stilo antes de criar o grafico, para voltar ao normal usar - ('default')
style.use('ggplot')
plt.plot(death_toll['Month'], death_toll['New_deaths'])
plt.show()
style.use('default')
plt.plot(death_toll['Month'], death_toll['New_deaths'])
plt.show()

# %%
#todos styles
style.available
# Out:
# ['Solarize_Light2',
#  '_classic_test_patch',
#  'bmh',
#  'classic',
#  'dark_background',
#  'fast',
#  'fivethirtyeight',
#  'ggplot',
#  'grayscale',
#  'seaborn',
#  'seaborn-bright',
#  'seaborn-colorblind',
#  'seaborn-dark',
#  'seaborn-dark-palette',
#  'seaborn-darkgrid',
#  'seaborn-deep',
#  'seaborn-muted',
#  'seaborn-notebook',
#  'seaborn-paper',
#  'seaborn-pastel',
#  'seaborn-poster',
#  'seaborn-talk',
#  'seaborn-ticks',
#  'seaborn-white',
#  'seaborn-whitegrid',
#  'tableau-colorblind10']

# %% [markdown]
# EXERCICIO

# %%
red_wine = pd.read_csv('/content/drive/MyDrive/Dados python/winequality-red.csv', sep=';')
#                               -1 remover a ultima linha['qualidade']
red_corr = red_wine.corr()['quality'][:-1]
red_corr

white_wine = pd.read_csv('/content/drive/MyDrive/Dados python/winequality-white.csv', sep=';')
white_corr = white_wine.corr()['quality'][:-1]
white_corr
# Out:
# fixed acidity          -0.113663
# volatile acidity       -0.194723
# citric acid            -0.009209
# residual sugar         -0.097577
# chlorides              -0.209934
# free sulfur dioxide     0.008158
# total sulfur dioxide   -0.174737
# density                -0.307123
# pH                      0.099427
# sulphates               0.053678
# alcohol                 0.435575
# Name: quality, dtype: float64

# %%
#from IPython.core.pylabtools import figsize

style.use('fivethirtyeight')
fig, ax = plt.subplots(figsize=(9,5))


#cria uma lista com true e false de cada valor
positivo_branca = white_corr >= 0

#                   map-para cada valor->se true=azul, se false=amarelo
cor_branco = positivo_branca.map({True:'#33A1C9',
                                  False:'#ffae42'})


positvo_vermelho = red_corr >=0
cor_vermelha = positvo_vermelho.map({True:'#33A1C9',
                                  False:'#ffae42'})

#                            left->mover as barras para o lado
ax.barh(white_corr.index, white_corr,left=2, height=0.5,color=cor_branco)

                                #largura da barra
ax.barh(red_corr.index, red_corr,height=0.5,left=-0.1,color=cor_vermelha)

#remover grade or b=False
ax.grid(axis='both')

#Remover as etiquetas
ax.set_yticklabels([])
ax.set_xticklabels([])


#=-=-=-=-=-=-=-=-=
#adicionar os rotulos
x_coords = {'Alcool' : 0.82, 'Sulfatos':0.77, 'ph':0.91, 'Density':0.80, 'Total Sulfur Dioxide':0.59, 'Free Sulfur Dioxide':0.6, 'Chlorides':0.77
            , 'Residual Sugar':0.67, 'Citric Acidit':0.76, 'Volatile Acidity':0.67, 'Fixed Acidity':0.71}

y_coord = 9.8

for y_label, x_coord in x_coords.items():
  ax.text(x_coord,y_coord,y_label)
  y_coord -=1

#linha vertical
ax.axvline(x=0.5,ymin=0.1,ymax=0.9,color='grey',alpha=0.1,linewidth=2)
ax.axvline(x=1.45,ymin=0.1,ymax=0.9,color='grey',alpha=0.1,linewidth=2)

#linha Horizontal
ax.axhline(-1, color='grey', linewidth=2,alpha=0.5,xmin=0.01,xmax=0.32)
ax.axhline(-1, color='grey', linewidth=2,alpha=0.5,xmin=0.67,xmax=0.98)

#xtick
ax.text(-0.7,-1.7,'-0.5' + ' ' * 31 + '+0.5', color='grey', alpha=0.5)
ax.text(1.43,-1.7,'-0.5' + ' ' * 31 + '+0.5', color='grey', alpha=0.5)

#linha horizontal acima do grafico
ax.axhline(11, color='grey',linewidth=1,alpha=0.5,xmin=0.01,xmax=0.32)
ax.axhline(11, color='grey',linewidth=1,alpha=0.5,xmin=0.67,xmax=0.98)

#titulo do coluna acima da linha
ax.text(x=-0.33,y=11.2,s='RED WINE',weight='bold')
ax.text(x=1.75,y=11.2,s='WHITE WINE',weight='bold')

#barra de assinatura e fonte de dados
ax.text(x=-0.7,y=-2.9,s='@LUIGI FERRARI' + ' ' * 94 + 'Fonte: P. Cortez er al. ', color='#f0f0f0', backgroundcolor = '#4d4d4d', size=12)

#titulo geral
ax.text(-0.7, 13.5, 'Wine Quality Most Strong Correlated With Alcohol Level.', size=17,weight='bold')
#subtitulo
ax.text(-0.7,12.7,'Correlation values between wine quality and wine properties (alcohol, ph, etc.)')


plt.show()

# %% [markdown]
# #analise de dados ENEM

# %%
enem = pd.read_csv("/content/drive/MyDrive/Dados python/MICRODADOS_ENEM_2020.csv", sep=";", encoding='ISO-8859-1', nrows=1000000)

# %% [markdown]
# Ver colunas dos dados

# %%
enem.columns.values
# Out:
# array(['NU_INSCRICAO', 'NU_ANO', 'TP_FAIXA_ETARIA', 'TP_SEXO',
#        'TP_ESTADO_CIVIL', 'TP_COR_RACA', 'TP_NACIONALIDADE',
#        'TP_ST_CONCLUSAO', 'TP_ANO_CONCLUIU', 'TP_ESCOLA', 'TP_ENSINO',
#        'IN_TREINEIRO', 'CO_MUNICIPIO_ESC', 'NO_MUNICIPIO_ESC',
#        'CO_UF_ESC', 'SG_UF_ESC', 'TP_DEPENDENCIA_ADM_ESC',
#        'TP_LOCALIZACAO_ESC', 'TP_SIT_FUNC_ESC', 'CO_MUNICIPIO_PROVA',
#        'NO_MUNICIPIO_PROVA', 'CO_UF_PROVA', 'SG_UF_PROVA',
#        'TP_PRESENCA_CN', 'TP_PRESENCA_CH', 'TP_PRESENCA_LC',
#        'TP_PRESENCA_MT', 'CO_PROVA_CN', 'CO_PROVA_CH', 'CO_PROVA_LC',
#        'CO_PROVA_MT', 'NU_NOTA_CN', 'NU_NOTA_CH', 'NU_NOTA_LC',
#        'NU_NOTA_MT', 'TX_RESPOSTAS_CN', 'TX_RESPOSTAS_CH',
#        'TX_RESPOSTAS_LC', 'TX_RESPOSTAS_MT', 'TP_LINGUA',
#        'TX_GABARITO_CN', 'TX_GABARITO_CH', 'TX_GABARITO_LC',
#        'TX_GABARITO_MT', 'TP_STATUS_REDACAO', 'NU_NOTA_COMP1',
#        'NU_NOTA_COMP2', 'NU_NOTA_COMP3', 'NU_NOTA_COMP4', 'NU_NOTA_COMP5',
# ...

# %%
enem.isnull().sum
# Out:
# <bound method NDFrame._add_numeric_operations.<locals>.sum of         NU_INSCRICAO  NU_ANO  TP_FAIXA_ETARIA  TP_SEXO  TP_ESTADO_CIVIL  \
# 0              False   False            False    False            False
# 1              False   False            False    False            False
# 2              False   False            False    False            False
# 3              False   False            False    False            False
# 4              False   False            False    False            False
# ...              ...     ...              ...      ...              ...
# 999995         False   False            False    False            False
# 999996         False   False            False    False            False
# 999997         False   False            False    False            False
# 999998         False   False            False    False            False
# 999999         False   False            False    False            False
#
# ...

# %%
#ver valores unciso da coluna 
enem['TP_ESTADO_CIVIL'].unique()
# Out:
# array([1, 2, 0, 3, 4])

# %% [markdown]
# copiar os dados e criar uma lista com os nomes das colunas

# %%
colunasSelecionadasEnem = ['NU_INSCRICAO', 'NU_ANO', 'TP_FAIXA_ETARIA', 'TP_SEXO',
       'TP_ESTADO_CIVIL', 'TP_COR_RACA', 'TP_NACIONALIDADE',
       'TP_ST_CONCLUSAO', 'TP_ANO_CONCLUIU', 'TP_ESCOLA', 'TP_ENSINO',
       'IN_TREINEIRO', 'CO_MUNICIPIO_ESC', 'NO_MUNICIPIO_ESC',
       'CO_UF_ESC', 'SG_UF_ESC', 'TP_DEPENDENCIA_ADM_ESC',
       'TP_LOCALIZACAO_ESC', 'TP_SIT_FUNC_ESC', 'CO_MUNICIPIO_PROVA',
       'NO_MUNICIPIO_PROVA', 'CO_UF_PROVA', 'SG_UF_PROVA',
       'TP_PRESENCA_CN', 'TP_PRESENCA_CH', 'TP_PRESENCA_LC',
       'TP_PRESENCA_MT', 'CO_PROVA_CN', 'CO_PROVA_CH', 'CO_PROVA_LC',
       'CO_PROVA_MT', 'NU_NOTA_CN', 'NU_NOTA_CH', 'NU_NOTA_LC',
       'NU_NOTA_MT', 'TX_RESPOSTAS_CN', 'TX_RESPOSTAS_CH',
       'TX_RESPOSTAS_LC', 'TX_RESPOSTAS_MT', 'TP_LINGUA',
       'TX_GABARITO_CN', 'TX_GABARITO_CH', 'TX_GABARITO_LC',
       'TX_GABARITO_MT', 'TP_STATUS_REDACAO', 'NU_NOTA_COMP1',
       'NU_NOTA_COMP2', 'NU_NOTA_COMP3', 'NU_NOTA_COMP4', 'NU_NOTA_COMP5',
       'NU_NOTA_REDACAO', 'Q001', 'Q002', 'Q003', 'Q004', 'Q005', 'Q006',
       'Q007', 'Q008', 'Q009', 'Q010', 'Q011', 'Q012', 'Q013', 'Q014',
       'Q015', 'Q016', 'Q017', 'Q018', 'Q019', 'Q020', 'Q021', 'Q022',
       'Q023', 'Q024', 'Q025']

# %% [markdown]
# variavel das colunas que vai usar = ['x', 'y']
#
#
# nomeVariavel = nometabela.FILTER( para filtrar as colunas que vc quer usar ) items=variavel das colunas que vai usar

# %%
enemSelecionado = enem.filter(items=colunasSelecionadasEnem)

# %%
enemSelecionado
# Out:
#         NU_INSCRICAO  NU_ANO  TP_FAIXA_ETARIA TP_SEXO  TP_ESTADO_CIVIL  \
# 0       200006271946    2020               11       F                1
# 1       200001195856    2020               11       M                2
# 2       200001943954    2020                4       F                2
# 3       200001908998    2020                2       M                1
# 4       200001634757    2020                4       F                1
# ...              ...     ...              ...     ...              ...
# 999995  200006515317    2020               11       M                2
# 999996  200003790136    2020               11       F                1
# 999997  200005095024    2020                2       F                1
# 999998  200003727683    2020                3       M                1
# 999999  200006199115    2020                6       F                1
#
#         TP_COR_RACA  TP_NACIONALIDADE  TP_ST_CONCLUSAO  TP_ANO_CONCLUIU  \
# ...

# %% [markdown]
# Quantidade de candidator por cor/raca

# %%
coluna_cor_raca=enem['TP_COR_RACA']
coluna_cor_raca
# Out:
# 0         2
# 1         3
# 2         3
# 3         3
# 4         3
#          ..
# 999995    3
# 999996    3
# 999997    3
# 999998    1
# 999999    3
# Name: TP_COR_RACA, Length: 1000000, dtype: int64

# %%
coluna_cor_raca.value_counts()
# Out:
# 3    467835
# 1    356235
# 2    127936
# 4     23122
# 0     18973
# 5      5899
# Name: TP_COR_RACA, dtype: int64

# %%
coluna_cor_raca.value_counts().plot(kind='pie')

# %%
coluna_sexo = enem['TP_SEXO']
coluna_sexo.value_counts().sort_index()
countsex = coluna_sexo.value_counts().sort_index()
countsex
# Out:
# F    658848
# M    341152
# Name: TP_SEXO, dtype: int64

# %%
coluna_sexo.value_counts().plot(kind='pie')

# %%
#outro tipo de coluna -HIST
coluna_sexo.hist(bins=30)

# %%
#percentual
percentualsexo = [100*x/countsex.sum() for x in countsex]
percentualsexo
# Out:
# [65.8848, 34.1152]

# %% [markdown]
# #quem tem melhor nota na redacao, meninos ou meninas?

# %%
colunasSelecionadasEnem = ['TP_SEXO','NU_NOTA_REDACAO']
sexoRedacao = enem.filter(items=colunasSelecionadasEnem)
sexoRedacao
# Out:
#        TP_SEXO  NU_NOTA_REDACAO
# 0            F              NaN
# 1            M            580.0
# 2            F              NaN
# 3            M            760.0
# 4            F              NaN
# ...        ...              ...
# 999995       M            560.0
# 999996       F              NaN
# 999997       F            520.0
# 999998       M            820.0
# 999999       F              NaN
#
# [1000000 rows x 2 columns]

# %% [markdown]
# Limpar as linhas vazias

# %%
sexoRedacao = sexoRedacao.dropna()
sexoRedacao
# Out:
#        TP_SEXO  NU_NOTA_REDACAO
# 1            M            580.0
# 3            M            760.0
# 5            F            700.0
# 7            M            600.0
# 8            F            600.0
# ...        ...              ...
# 999991       M            580.0
# 999992       F            480.0
# 999995       M            560.0
# 999997       F            520.0
# 999998       M            820.0
#
# [608457 rows x 2 columns]

# %%
#total M e F
sexoRedacao.groupby('TP_SEXO').count()
# Out:
#          NU_NOTA_REDACAO
# TP_SEXO
# F                 403303
# M                 205154

# %%
#nota maxima M e F
sexoRedacao.groupby('TP_SEXO').max()
# Out:
#          NU_NOTA_REDACAO
# TP_SEXO
# F                 1000.0
# M                 1000.0

# %%
#nota minima M e F
sexoRedacao.groupby('TP_SEXO').min()
# Out:
#          NU_NOTA_REDACAO
# TP_SEXO
# F                    0.0
# M                    0.0

# %%
#nota minima M e F > 0
sexoRedacao[sexoRedacao.NU_NOTA_REDACAO > 0].groupby('TP_SEXO').min()
# Out:
#          NU_NOTA_REDACAO
# TP_SEXO
# F                   40.0
# M                   40.0

# %%
#nota media M e F
sexoRedacao.groupby('TP_SEXO').mean()
# Out:
#          NU_NOTA_REDACAO
# TP_SEXO
# F             623.566797
# M             593.036938

# %%
#mediana
sexoRedacao.groupby('TP_SEXO').median()
# Out:
#          NU_NOTA_REDACAO
# TP_SEXO
# F                  620.0
# M                  600.0

# %%
#histograma
sexoRedacao.groupby('TP_SEXO').hist()
# Out:
# TP_SEXO
# F    [[AxesSubplot(0.08,0.07;0.87x0.81)]]
# M    [[AxesSubplot(0.08,0.07;0.87x0.81)]]
# dtype: object

# %%
#descricao -geral
sexoRedacao.groupby('TP_SEXO').describe()
# Out:
#         NU_NOTA_REDACAO                                                   \
#                   count        mean        std  min    25%    50%    75%
# TP_SEXO
# F              403303.0  623.566797  197.52720  0.0  500.0  620.0  780.0
# M              205154.0  593.036938  206.34657  0.0  480.0  600.0  740.0
#
#
#             max
# TP_SEXO
# F        1000.0
# M        1000.0

# %% [markdown]
# #filtro de acordo com nivel de escolaridade do pai e da mae

# %%
colunasSelecionadasEnem = ['NU_INSCRICAO', 'NU_NOTA_MT', 'NU_NOTA_REDACAO', 'Q001', 'Q002']
dadosSelecionados = enem.filter(items=colunasSelecionadasEnem)
dadosSelecionados
# Out:
#         NU_INSCRICAO  NU_NOTA_MT  NU_NOTA_REDACAO Q001 Q002
# 0       200006271946         NaN              NaN  NaN  NaN
# 1       200001195856       711.3            580.0  NaN  NaN
# 2       200001943954         NaN              NaN    B    C
# 3       200001908998       759.4            760.0  NaN  NaN
# 4       200001634757         NaN              NaN    B    G
# ...              ...         ...              ...  ...  ...
# 999995  200006515317       551.1            560.0    E    H
# 999996  200003790136         NaN              NaN    C    B
# 999997  200005095024       600.3            520.0    B    B
# 999998  200003727683       731.7            820.0    F    C
# 999999  200006199115         NaN              NaN    B    B
#
# [1000000 rows x 5 columns]

# %%
dadosSelecionados = dadosSelecionados.dropna()
dadosSelecionados
# Out:
#         NU_INSCRICAO  NU_NOTA_MT  NU_NOTA_REDACAO Q001 Q002
# 5       200003132410       526.7            700.0    C    B
# 8       200006762554       448.5            600.0    B    C
# 11      200006138472       546.5            640.0    B    C
# 18      200003343448       420.3            800.0    C    C
# 19      200005966328       405.6            500.0    C    D
# ...              ...         ...              ...  ...  ...
# 999991  200002576499       592.8            580.0    B    E
# 999992  200002047018       545.6            480.0    C    C
# 999995  200006515317       551.1            560.0    E    H
# 999997  200005095024       600.3            520.0    B    B
# 999998  200003727683       731.7            820.0    F    C
#
# [556602 rows x 5 columns]

# %%
#informacoes q01 e q02 dicionario
dicionario01e02 = {'A':'Nunca Estudou',
                   'B':'não completou a 4/5 serie do fundamental',
                   'C':'completou a 4/5 do fundamental masn a 8/9',
                   'D':'completou a 8/9 mas n o ensino medio',
                   'E':'completou o ensino medio mas n a facul',
                   'F':'completou a faculdade mas n a pos',
                   'G':'Completou pos graduacao',
                   'H':'N sei',}

# %%
enem.filter(items=['Q001','NU_INSCRICAO']).groupby('Q001').count()
# Out:
#       NU_INSCRICAO
# Q001
# A            45343
# B           192792
# C           136235
# D           107257
# E           255266
# F            65210
# G            42006
# H            83111

# %% [markdown]
# Criar um coluna relacionando

# %%
dadosSelecionados['NO_Q001'] = [dicionario01e02[resp] for resp in dadosSelecionados.Q001]
dadosSelecionados['NO_Q002'] = [dicionario01e02[resp] for resp in dadosSelecionados.Q002]
dadosSelecionados.head()
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#     NU_INSCRICAO  NU_NOTA_MT  NU_NOTA_REDACAO Q001 Q002  \
# 5   200003132410       526.7            700.0    C    B
# 8   200006762554       448.5            600.0    B    C
# ...

# %%
#sort_values(a tabela que vc quer por em ordem) ---- ascending (menor p maior) ascending False (maior pra menor)
#pais
dadosSelecionados.filter(items=['NU_INSCRICAO','NO_Q001']).groupby('NO_Q001').count().sort_values(by='NU_INSCRICAO', ascending=False)
# Out:
#                                            NU_INSCRICAO
# NO_Q001
# completou o ensino medio mas n a facul           167294
# não completou a 4/5 serie do fundamental          96967
# completou a 4/5 do fundamental masn a 8/9         77696
# completou a 8/9 mas n o ensino medio              65578
# completou a faculdade mas n a pos                 49108
# N sei                                             45439
# Completou pos graduacao                           32945
# Nunca Estudou                                     21575

# %%
#maes
dadosSelecionados.filter(items=['NU_INSCRICAO','NO_Q002']).groupby('NO_Q002').count().sort_values(by='NU_INSCRICAO', ascending=False)
# Out:
#                                            NU_INSCRICAO
# NO_Q002
# completou o ensino medio mas n a facul           203449
# não completou a 4/5 serie do fundamental          68963
# completou a 8/9 mas n o ensino medio              68112
# completou a faculdade mas n a pos                 66628
# completou a 4/5 do fundamental masn a 8/9         66527
# Completou pos graduacao                           57618
# Nunca Estudou                                     13419
# N sei                                             11886

# %%
# MAIORES MEDIAS DE MA - pai
dadosSelecionados.filter(items=['NU_NOTA_MT','NO_Q001']).groupby('NO_Q001').mean().sort_values(by='NU_NOTA_MT', ascending=False)
# Out:
#                                            NU_NOTA_MT
# NO_Q001
# Completou pos graduacao                    635.743503
# completou a faculdade mas n a pos          610.766944
# completou o ensino medio mas n a facul     538.464417
# completou a 8/9 mas n o ensino medio       515.212054
# completou a 4/5 do fundamental masn a 8/9  502.598620
# N sei                                      495.379344
# não completou a 4/5 serie do fundamental   482.514170
# Nunca Estudou                              459.131685

# %%
# MAIORES MEDIAS DE MA - mae
dadosSelecionados.filter(items=['NU_NOTA_MT','NO_Q002']).groupby('NO_Q002').mean().sort_values(by='NU_NOTA_MT', ascending=False)
# Out:
#                                            NU_NOTA_MT
# NO_Q002
# Completou pos graduacao                    609.221212
# completou a faculdade mas n a pos          590.503875
# completou o ensino medio mas n a facul     527.198238
# completou a 8/9 mas n o ensino medio       502.496647
# completou a 4/5 do fundamental masn a 8/9  491.553688
# N sei                                      478.647400
# não completou a 4/5 serie do fundamental   473.811748
# Nunca Estudou                              451.839653

# %%
q002MT = dadosSelecionados.filter(items=['NU_NOTA_MT','NO_Q002']).groupby('NO_Q002').mean().sort_values(by='NU_NOTA_MT', ascending=False)
q002MT.plot()

# %% [markdown]
# #Media de notas por tipo de escolas

# %%
dadosSelecionados=['NU_NOTA_MT','TP_ESCOLA']
mediaEscolas = enem.filter(items=dadosSelecionados)
mediaEscolas
# Out:
#         NU_NOTA_MT  TP_ESCOLA
# 0              NaN          1
# 1            711.3          1
# 2              NaN          2
# 3            759.4          2
# 4              NaN          1
# ...            ...        ...
# 999995       551.1          1
# 999996         NaN          2
# 999997       600.3          1
# 999998       731.7          3
# 999999         NaN          1
#
# [1000000 rows x 2 columns]

# %%
dicionarioEscola = {1:'Não respondeu',
                    2:'Pública',
                    3:'Privada',
                    4:'Exterior',}

# %%
mediaEscolas['NOMES_TP_ESCOLA'] = [dicionarioEscola[e] for e in mediaEscolas.TP_ESCOLA]
mediaEscolas
# Out:
#         NU_NOTA_MT  TP_ESCOLA NOMES_TP_ESCOLA
# 0              NaN          1   Não respondeu
# 1            711.3          1   Não respondeu
# 2              NaN          2         Pública
# 3            759.4          2         Pública
# 4              NaN          1   Não respondeu
# ...            ...        ...             ...
# 999995       551.1          1   Não respondeu
# 999996         NaN          2         Pública
# 999997       600.3          1   Não respondeu
# 999998       731.7          3         Privada
# 999999         NaN          1   Não respondeu
#
# [1000000 rows x 3 columns]

# %%
mediaEscolas.dropna()
# Out:
#         NU_NOTA_MT  TP_ESCOLA NOMES_TP_ESCOLA
# 1            711.3          1   Não respondeu
# 3            759.4          2         Pública
# 5            526.7          1   Não respondeu
# 7            753.2          1   Não respondeu
# 8            448.5          1   Não respondeu
# ...            ...        ...             ...
# 999991       592.8          2         Pública
# 999992       545.6          2         Pública
# 999995       551.1          1   Não respondeu
# 999997       600.3          1   Não respondeu
# 999998       731.7          3         Privada
#
# [580238 rows x 3 columns]

# %%
mediaEscolas.groupby('NOMES_TP_ESCOLA').count()
mediaEscolas.filter(items=['NU_NOTA_MT', 'NOMES_TP_ESCOLA']).groupby('NOMES_TP_ESCOLA').count()
# Out:
#                  NU_NOTA_MT
# NOMES_TP_ESCOLA
# Não respondeu        327671
# Privada               45786
# Pública              206781

# %%
mediaEscolas.filter(items=['NU_NOTA_MT', 'NOMES_TP_ESCOLA']).groupby('NOMES_TP_ESCOLA').mean().sort_values(by='NU_NOTA_MT', ascending=False)
# Out:
#                  NU_NOTA_MT
# NOMES_TP_ESCOLA
# Privada          623.612895
# Não respondeu    525.658732
# Pública          505.191692

# %%
mediaEscolas.filter(items=['NU_NOTA_MT', 'NOMES_TP_ESCOLA']).groupby('NOMES_TP_ESCOLA').mean().plot(kind='bar')

# %%
#nota maxima de cada
mediaEscolas.filter(items=['NU_NOTA_MT', 'NOMES_TP_ESCOLA']).groupby('NOMES_TP_ESCOLA').min()
# Out:
#                  NU_NOTA_MT
# NOMES_TP_ESCOLA
# Não respondeu           0.0
# Privada                 0.0
# Pública                 0.0

# %%
#nota minima de cada
mediaEscolas.filter(items=['NU_NOTA_MT', 'NOMES_TP_ESCOLA']).groupby('NOMES_TP_ESCOLA').max()
# Out:
#                  NU_NOTA_MT
# NOMES_TP_ESCOLA
# Não respondeu         975.0
# Privada               975.0
# Pública               975.0

# %% [markdown]
# #nota redacao por escolaridade dos pais, em cada estado

# %%
enem.columns.values
# Out:
# array(['NU_INSCRICAO', 'NU_ANO', 'TP_FAIXA_ETARIA', 'TP_SEXO',
#        'TP_ESTADO_CIVIL', 'TP_COR_RACA', 'TP_NACIONALIDADE',
#        'TP_ST_CONCLUSAO', 'TP_ANO_CONCLUIU', 'TP_ESCOLA', 'TP_ENSINO',
#        'IN_TREINEIRO', 'CO_MUNICIPIO_ESC', 'NO_MUNICIPIO_ESC',
#        'CO_UF_ESC', 'SG_UF_ESC', 'TP_DEPENDENCIA_ADM_ESC',
#        'TP_LOCALIZACAO_ESC', 'TP_SIT_FUNC_ESC', 'CO_MUNICIPIO_PROVA',
#        'NO_MUNICIPIO_PROVA', 'CO_UF_PROVA', 'SG_UF_PROVA',
#        'TP_PRESENCA_CN', 'TP_PRESENCA_CH', 'TP_PRESENCA_LC',
#        'TP_PRESENCA_MT', 'CO_PROVA_CN', 'CO_PROVA_CH', 'CO_PROVA_LC',
#        'CO_PROVA_MT', 'NU_NOTA_CN', 'NU_NOTA_CH', 'NU_NOTA_LC',
#        'NU_NOTA_MT', 'TX_RESPOSTAS_CN', 'TX_RESPOSTAS_CH',
#        'TX_RESPOSTAS_LC', 'TX_RESPOSTAS_MT', 'TP_LINGUA',
#        'TX_GABARITO_CN', 'TX_GABARITO_CH', 'TX_GABARITO_LC',
#        'TX_GABARITO_MT', 'TP_STATUS_REDACAO', 'NU_NOTA_COMP1',
#        'NU_NOTA_COMP2', 'NU_NOTA_COMP3', 'NU_NOTA_COMP4', 'NU_NOTA_COMP5',
# ...

# %%
colunasSelecionadas = ['NU_INSCRICAO','SG_UF_ESC', 'NU_NOTA_MT', 'NU_NOTA_REDACAO', 'Q001', 'Q002']

dadosSelecionados = enem.filter(items=colunasSelecionadas).dropna()
dadosSelecionados
# Out:
#         NU_INSCRICAO SG_UF_ESC  NU_NOTA_MT  NU_NOTA_REDACAO Q001 Q002
# 36      200003209996        AM       433.9            620.0    E    E
# 65      200003350911        PI       384.2            880.0    A    C
# 84      200005725669        MT       404.6            600.0    C    E
# 89      200004462096        SP       669.8            820.0    B    C
# 93      200002727241        RJ       743.0            920.0    E    E
# ...              ...       ...         ...              ...  ...  ...
# 999964  200002196143        CE       387.8            300.0    D    D
# 999965  200001295206        CE       438.0            540.0    A    C
# 999986  200002346202        ES       395.2            340.0    D    D
# 999989  200006493853        GO       692.2            640.0    D    D
# 999998  200003727683        PR       731.7            820.0    F    C
#
# [154026 rows x 6 columns]

# %%
#informacoes q01 e q02 dicionario
dicionario01e02 = {'A':'Nunca Estudou',
                   'B':'não completou a 4/5 serie do fundamental',
                   'C':'completou a 4/5 do fundamental masn a 8/9',
                   'D':'completou a 8/9 mas n o ensino medio',
                   'E':'completou o ensino medio mas n a facul',
                   'F':'completou a faculdade mas n a pos',
                   'G':'Completou pos graduacao',
                   'H':'N sei',}

# %%
dadosSelecionados['NO_Q001'] = [dicionario01e02[e] for e in dadosSelecionados.Q001]

# %%
dadosSelecionados['NO_Q002'] = [dicionario01e02[e] for e in dadosSelecionados.Q002]

# %%
#WHERE UF == RJ
dadosSelecionados.filter(items=['NO_Q002', 'NU_NOTA_REDACAO'])\
.where(dadosSelecionados.SG_UF_ESC == 'RJ')\
.groupby('NO_Q002')\
.mean().sort_values(by='NU_NOTA_REDACAO', ascending=False)
# Out:
#                                            NU_NOTA_REDACAO
# NO_Q002
# Completou pos graduacao                         792.255193
# completou a faculdade mas n a pos               760.288840
# completou o ensino medio mas n a facul          658.573596
# completou a 8/9 mas n o ensino medio            621.286713
# N sei                                           617.536946
# completou a 4/5 do fundamental masn a 8/9       606.678540
# não completou a 4/5 serie do fundamental        594.590417
# Nunca Estudou                                   594.000000

# %%
#WHERE UF == MG
dadosSelecionados.filter(items=['NO_Q002', 'NU_NOTA_REDACAO'])\
.where(dadosSelecionados.SG_UF_ESC == 'MG')\
.groupby('NO_Q002')\
.mean().sort_values(by='NU_NOTA_REDACAO', ascending=False)
# Out:
#                                            NU_NOTA_REDACAO
# NO_Q002
# Completou pos graduacao                         801.885550
# completou a faculdade mas n a pos               769.453725
# completou o ensino medio mas n a facul          703.853531
# completou a 8/9 mas n o ensino medio            659.624343
# completou a 4/5 do fundamental masn a 8/9       646.168067
# não completou a 4/5 serie do fundamental        613.371758
# N sei                                           610.869565
# Nunca Estudou                                   558.431373

# %%
#TODAS AS REGIOES
dadosSelecionados.filter(items=['SG_UF_ESC','NO_Q002', 'NU_NOTA_REDACAO'])\
.groupby(['SG_UF_ESC','NO_Q002'])\
.mean()
# Out:
#                                                      NU_NOTA_REDACAO
# SG_UF_ESC NO_Q002
# AC        Completou pos graduacao                         679.658120
#           N sei                                           646.363636
#           Nunca Estudou                                   527.272727
#           completou a 4/5 do fundamental masn a 8/9       584.000000
#           completou a 8/9 mas n o ensino medio            610.400000
# ...                                                              ...
# TO        completou a 4/5 do fundamental masn a 8/9       579.444444
#           completou a 8/9 mas n o ensino medio            589.113924
#           completou a faculdade mas n a pos               654.680851
#           completou o ensino medio mas n a facul          617.287234
#           não completou a 4/5 serie do fundamental        578.545455
#
# [216 rows x 1 columns]

# %%
#Pacote para facilitar a visualizacao
import matplotlib.pyplot as plt

# %%
ax= dadosSelecionados.filter(items=['SG_UF_ESC','Q002', 'NU_NOTA_REDACAO'])\
.where(dadosSelecionados.Q002 != 'H')\
.groupby(['Q002','SG_UF_ESC'])\
.mean().sort_values(by='NU_NOTA_REDACAO', ascending=False)\
.unstack().plot(figsize=(16,8))

ax.set_title("Nota redacao x escolaridade x estado")
#ax.legend(bbox_to_anchor=(1,1), loc=0, borderaxespad=0)

handles, labels = ax.get_legend_handles_labels()

import re
edited_labels = [re.search(',\s(.+?)\)', label).group(1) for label in labels]
ax.legend(edited_labels, bbox_to_anchor=(1,1), loc=0, borderaxespad=0)

textdict = ""
for k, v in dicionario01e02.items():
  textdict = textdict + "{key} : {value}\n".format(key=k, value=v)

ax.text(0,1, textdict, transform=ax.transAxes, fontsize=14)
# Out:
# Text(0, 1, 'A : Nunca Estudou\nB : não completou a 4/5 serie do fundamental\nC : completou a 4/5 do fundamental masn a 8/9\nD : completou a 8/9 mas n o ensino medio\nE : completou o ensino medio mas n a facul\nF : completou a faculdade mas n a pos\nG : Completou pos graduacao\nH : N sei\n')

# %% [markdown]
# #Media em cada disciplina por municipio

# %%
enem.columns.values
# Out:
# array(['NU_INSCRICAO', 'NU_ANO', 'TP_FAIXA_ETARIA', 'TP_SEXO',
#        'TP_ESTADO_CIVIL', 'TP_COR_RACA', 'TP_NACIONALIDADE',
#        'TP_ST_CONCLUSAO', 'TP_ANO_CONCLUIU', 'TP_ESCOLA', 'TP_ENSINO',
#        'IN_TREINEIRO', 'CO_MUNICIPIO_ESC', 'NO_MUNICIPIO_ESC',
#        'CO_UF_ESC', 'SG_UF_ESC', 'TP_DEPENDENCIA_ADM_ESC',
#        'TP_LOCALIZACAO_ESC', 'TP_SIT_FUNC_ESC', 'CO_MUNICIPIO_PROVA',
#        'NO_MUNICIPIO_PROVA', 'CO_UF_PROVA', 'SG_UF_PROVA',
#        'TP_PRESENCA_CN', 'TP_PRESENCA_CH', 'TP_PRESENCA_LC',
#        'TP_PRESENCA_MT', 'CO_PROVA_CN', 'CO_PROVA_CH', 'CO_PROVA_LC',
#        'CO_PROVA_MT', 'NU_NOTA_CN', 'NU_NOTA_CH', 'NU_NOTA_LC',
#        'NU_NOTA_MT', 'TX_RESPOSTAS_CN', 'TX_RESPOSTAS_CH',
#        'TX_RESPOSTAS_LC', 'TX_RESPOSTAS_MT', 'TP_LINGUA',
#        'TX_GABARITO_CN', 'TX_GABARITO_CH', 'TX_GABARITO_LC',
#        'TX_GABARITO_MT', 'TP_STATUS_REDACAO', 'NU_NOTA_COMP1',
#        'NU_NOTA_COMP2', 'NU_NOTA_COMP3', 'NU_NOTA_COMP4', 'NU_NOTA_COMP5',
# ...

# %%
colunasSelecionadas = ['SG_UF_ESC','CO_MUNICIPIO_ESC','NU_NOTA_CN', 'NU_NOTA_CH', 'NU_NOTA_LC', 'NU_NOTA_MT', 'NU_NOTA_REDACAO']

dadosSelecionados = enem.filter(items=colunasSelecionadas).dropna()

dadosSelecionados
# Out:
#        SG_UF_ESC  CO_MUNICIPIO_ESC  NU_NOTA_CN  NU_NOTA_CH  NU_NOTA_LC  \
# 3             SP         3547304.0       620.8       675.0       624.2
# 36            AM         1302009.0       486.9       509.7       532.3
# 65            PI         2207009.0       516.8       565.7       567.7
# 84            MT         5108402.0       467.5       518.8       541.0
# 89            SP         3513603.0       578.4       681.1       638.2
# ...          ...               ...         ...         ...         ...
# 999964        CE         2311306.0       396.3       513.0       496.3
# 999965        CE         2304400.0       520.7       555.6       528.0
# 999986        ES         3203056.0       422.3       388.7       370.4
# 999989        GO         5211008.0       590.3       672.5       584.1
# 999998        PR         4104808.0       641.5       698.9       663.7
#
#         NU_NOTA_MT  NU_NOTA_REDACAO
# 3            759.4            760.0
# 36           433.9            620.0
# ...

# %%
mediaporMunicipio = dadosSelecionados.groupby(['CO_MUNICIPIO_ESC','SG_UF_ESC'], as_index=False).mean()
mediaporMunicipio
# Out:
#       CO_MUNICIPIO_ESC SG_UF_ESC  NU_NOTA_CN  NU_NOTA_CH  NU_NOTA_LC  \
# 0            1100015.0        RO  515.045455  549.354545  546.322727
# 1            1100023.0        RO  488.038000  510.432000  524.336000
# 2            1100031.0        RO  493.366667  487.233333  537.366667
# 3            1100049.0        RO  508.368750  541.611250  539.527500
# 4            1100056.0        RO  440.455556  484.733333  497.688889
# ...                ...       ...         ...         ...         ...
# 4414         5221908.0        GO  434.500000  416.900000  441.200000
# 4415         5222005.0        GO  466.675000  482.587500  528.187500
# 4416         5222054.0        GO  499.825000  548.325000  563.875000
# 4417         5222302.0        GO  394.900000  493.700000  500.300000
# 4418         5300108.0        DF  516.080170  546.687886  557.619033
#
#       NU_NOTA_MT  NU_NOTA_REDACAO
# 0     539.663636       704.545455
# 1     514.474000       600.800000
# ...

# %%
mediaporMunicipio = dadosSelecionados.groupby(['SG_UF_ESC'], as_index=False).mean()
#mediaporMunicipio
mediaporMunicipio.sort_values('NU_NOTA_REDACAO')
# Out:
#    SG_UF_ESC  CO_MUNICIPIO_ESC  NU_NOTA_CN  NU_NOTA_CH  NU_NOTA_LC  \
# 2         AM      1.302520e+06  470.460150  501.880806  503.829682
# 21        RR      1.400119e+06  486.449319  510.285014  525.828065
# 5         CE      2.306172e+06  474.077529  497.018165  511.640213
# 0         AC      1.200382e+06  480.008071  505.936799  521.174282
# 9         MA      2.107943e+06  479.314321  503.023436  515.788606
# 3         AP      1.600374e+06  479.213715  502.822743  517.913368
# 20        RO      1.100254e+06  485.241146  510.514211  521.483854
# 26        TO      1.712720e+06  489.750591  514.214567  527.291732
# 15        PE      2.609171e+06  491.889743  512.608137  530.072904
# 4         BA      2.920053e+06  496.688186  523.063855  533.855658
# 1         AL      2.704317e+06  486.274600  510.367686  524.488777
# 13        PA      1.502873e+06  484.379559  508.478241  520.665843
# 12        MT      5.105066e+06  500.913921  529.688330  538.269069
# ...

# %%
#fazer download
#mediaporMunicipio.to_csv("mediaEnemMunicipio.csv")

# %% [markdown]
# #Juntar dois dataframes com uma coluna em comum

# %%
#MERGE --  os dataframes --             usando o da esqueda de base -- nome tabela esquerda --        nome coluna, do dataframe da direita

# VARIAVEL = pd.merge(enem, atlasHumano, how='left',                   left_on=['CO_MUNICIPIO_ESC'],  right_on['Codmun7'])

# %%
#VER TIPO DAS COLUNAS DO DATAFRAME
enem.dtypes
# Out:
# NU_INSCRICAO        int64
# NU_ANO              int64
# TP_FAIXA_ETARIA     int64
# TP_SEXO            object
# TP_ESTADO_CIVIL     int64
#                     ...
# Q021               object
# Q022               object
# Q023               object
# Q024               object
# Q025               object
# Length: 76, dtype: object

# %%
#transformar um objeto ex = 1,32 para float
numero = "0,34"
numero = float(str(numero).replace(",","."))
numero

#No data frame                              lambda = para cada elemento recebido x: vai fazer ->
#mediaEnem['IDHM'] = mediaEnem['IDHM'].apply(lambda x: float(str(x).replace(",",".")))
# Out:
# 0.34

# %%
#map vai pegar cada elemento da lista -> lambda "funcao", lista que vai usar
lista = [1,3,5,7]

novalista = list(map(lambda x: x*3, lista))
print(novalista)
# Out:
# [3, 9, 15, 21]

# %% [markdown]
# #criar nova coluna com o valor do produto + imposto que foi aplicado

# %%
vendas = pd.read_csv('/content/drive/MyDrive/Dados python/Base Vendas.xlsx - Vendas 2019.csv', encoding='utf-8')

vendas.head()
# Out:
#       SKU      Produto  Quantidade Vendida Primeiro Nome   Sobrenome  \
# 0  HL4379   Televisão                    5       Gabriel       Thoni
# 1  HL4379   Televisão                    3         Renan  Nascimento
# 2  HL1148      Câmera                    2        Camila      Sobral
# 3  HL1918      iPhone                    3         Clara       Bruno
# 4  HL9962     Android                    4       Eduardo     Pacheco
#
#          Data       Loja Preco Unitario
# 0   6/30/2018   Curitiba    R$ 2.500,00
# 1   9/14/2018     Recife    R$ 2.500,00
# 2  10/21/2018  Fortaleza    R$ 2.100,00
# 3    7/8/2018  Fortaleza    R$ 5.300,00
# 4  12/19/2018  Fortaleza    R$ 3.400,00

# %%
vendas.dtypes
# Out:
# SKU                   object
# Produto               object
# Quantidade Vendida     int64
# Primeiro Nome         object
# Sobrenome             object
# Data                  object
# Loja                  object
# Preco Unitario        object
# dtype: object

# %%
vendas.describe(include='all')
# Out:
#            SKU   Produto  Quantidade Vendida Primeiro Nome Sobrenome  \
# count     9999      9999         9999.000000          9999      9999
# unique       7         7                 NaN           260       343
# top     HL1918   iPhone                  NaN         Lucas     Silva
# freq      2977      2977                 NaN           332       394
# mean       NaN       NaN            3.004600           NaN       NaN
# std        NaN       NaN            1.405409           NaN       NaN
# min        NaN       NaN            1.000000           NaN       NaN
# 25%        NaN       NaN            2.000000           NaN       NaN
# 50%        NaN       NaN            3.000000           NaN       NaN
# 75%        NaN       NaN            4.000000           NaN       NaN
# max        NaN       NaN            5.000000           NaN       NaN
#
#              Data       Loja Preco Unitario
# count        9999       9999           9999
# unique        365          9              7
# ...

# %%
#converter o valor do objeto para float
vendas['Preco Unitario'] = vendas['Preco Unitario'].apply(lambda x: float(x.replace(".","").replace(",",".").replace("R$" , "")))

# %%
vendas['Preco com Taxa'] = list(map(lambda x: x*1.1, vendas['Preco Unitario']))
vendas
# Out:
#          SKU       Produto  Quantidade Vendida Primeiro Nome   Sobrenome  \
# 0     HL4379    Televisão                    5       Gabriel       Thoni
# 1     HL4379    Televisão                    3         Renan  Nascimento
# 2     HL1148       Câmera                    2        Camila      Sobral
# 3     HL1918       iPhone                    3         Clara       Bruno
# 4     HL9962      Android                    4       Eduardo     Pacheco
# ...      ...           ...                 ...           ...         ...
# 9994  HL4379    Televisão                    2          Caio    Ferreira
# 9995  HL1148       Câmera                    5           Kim    Ferreira
# 9996  HL4379    Televisão                    5          Caio      Moraes
# 9997  HL1918       iPhone                    4        Norman       Jimbo
# 9998  HL7348   SmartWatch                    1      Vinícius     Antunes
#
#             Data          Loja  Preco Unitario  Preco com Taxa
# ...

# %% [markdown]
# #pokemon

# %%
import pandas as pd
df = pd.read_csv("/content/drive/MyDrive/Dados python/pokemon_data.csv", sep=',')
df
# Out:
#        #                   Name   Type 1  Type 2  HP  Attack  Defense  \
# 0      1              Bulbasaur    Grass  Poison  45      49       49
# 1      2                Ivysaur    Grass  Poison  60      62       63
# 2      3               Venusaur    Grass  Poison  80      82       83
# 3      3  VenusaurMega Venusaur    Grass  Poison  80     100      123
# 4      4             Charmander     Fire     NaN  39      52       43
# ..   ...                    ...      ...     ...  ..     ...      ...
# 795  719                Diancie     Rock   Fairy  50     100      150
# 796  719    DiancieMega Diancie     Rock   Fairy  50     160      110
# 797  720    HoopaHoopa Confined  Psychic   Ghost  80     110       60
# 798  720     HoopaHoopa Unbound  Psychic    Dark  80     160       60
# 799  721              Volcanion     Fire   Water  80     110      120
#
#      Sp. Atk  Sp. Def  Speed  Generation  Legendary
# 0         65       65     45           1      False
# ...

# %%
df.columns
# Out:
# Index(['#', 'Name', 'Type 1', 'Type 2', 'HP', 'Attack', 'Defense', 'Sp. Atk',
#        'Sp. Def', 'Speed', 'Generation', 'Legendary'],
#       dtype='object')

# %%
#imprimir uma linha especifica
df.iloc[1]
# Out:
# #                   2
# Name          Ivysaur
# Type 1          Grass
# Type 2         Poison
# HP                 60
# Attack             62
# Defense            63
# Sp. Atk            80
# Sp. Def            80
# Speed              60
# Generation          1
# Legendary       False
# Name: 1, dtype: object

# %%
#imprimir linhas que possuem um certo valor
df.loc[df['Type 1'] == 'Fire']
# Out:
#        #                       Name Type 1    Type 2   HP  Attack  Defense  \
# 4      4                 Charmander   Fire       NaN   39      52       43
# 5      5                 Charmeleon   Fire       NaN   58      64       58
# 6      6                  Charizard   Fire    Flying   78      84       78
# 7      6  CharizardMega Charizard X   Fire    Dragon   78     130      111
# 8      6  CharizardMega Charizard Y   Fire    Flying   78     104       78
# 42    37                     Vulpix   Fire       NaN   38      41       40
# 43    38                  Ninetales   Fire       NaN   73      76       75
# 63    58                  Growlithe   Fire       NaN   55      70       45
# 64    59                   Arcanine   Fire       NaN   90     110       80
# 83    77                     Ponyta   Fire       NaN   50      85       55
# 84    78                   Rapidash   Fire       NaN   65     100       70
# ...

# %%
#ordem alfabetica, numerica...
df.sort_values(['Type 1','HP'], ascending=[1,0])
# Out:
#        #                     Name Type 1    Type 2  HP  Attack  Defense  \
# 520  469                  Yanmega    Bug    Flying  86      76       86
# 698  637                Volcarona    Bug      Fire  85      60       65
# 231  214                Heracross    Bug  Fighting  80     125       75
# 232  214  HeracrossMega Heracross    Bug  Fighting  80     185      115
# 678  617                 Accelgor    Bug       NaN  80      70       40
# ..   ...                      ...    ...       ...  ..     ...      ...
# 106   98                   Krabby  Water       NaN  30     105       90
# 125  116                   Horsea  Water       NaN  30      40       70
# 129  120                   Staryu  Water       NaN  30      45       55
# 139  129                 Magikarp  Water       NaN  20      10       55
# 381  349                   Feebas  Water       NaN  20      15       20
#
#      Sp. Atk  Sp. Def  Speed  Generation  Legendary
# ...

# %%
#somar todos poderes, vida etc para ver qual pokemon e o melhor
df['Total']= df['HP'] + df['Attack'] +df['Defense'] +df['Sp. Atk'] +df['Sp. Def'] + df['Speed'] 	
df.sort_values('Total', ascending=False).head()
# Out:
#        #                   Name   Type 1    Type 2   HP  Attack  Defense  \
# 426  384  RayquazaMega Rayquaza   Dragon    Flying  105     180      100
# 164  150    MewtwoMega Mewtwo Y  Psychic       NaN  106     150       70
# 163  150    MewtwoMega Mewtwo X  Psychic  Fighting  106     190      100
# 422  382    KyogrePrimal Kyogre    Water       NaN  100     150       90
# 424  383  GroudonPrimal Groudon   Ground      Fire  100     180      160
#
#      Sp. Atk  Sp. Def  Speed  Generation  Legendary  Total
# 426      180      100    115           3       True    780
# 164      194      120    140           1       True    780
# 163      154      100    130           1       True    780
# 422      180      160     90           3       True    770
# 424      150       90     90           3       True    770

# %%
#outra maneira de fazer o total - ILOC[:,] = TODAS AS LINHAS - DA COLUNA X A Y - AXIS = 1 (horizontal)
df['Total 2'] = df.iloc[:, 4:10].sum(axis=1)
df.head()
# Out:
#    #                   Name Type 1  Type 2  HP  Attack  Defense  Sp. Atk  \
# 0  1              Bulbasaur  Grass  Poison  45      49       49       65
# 1  2                Ivysaur  Grass  Poison  60      62       63       80
# 2  3               Venusaur  Grass  Poison  80      82       83      100
# 3  3  VenusaurMega Venusaur  Grass  Poison  80     100      123      122
# 4  4             Charmander   Fire     NaN  39      52       43       60
#
#    Sp. Def  Speed  Generation  Legendary  Total  Total 2
# 0       65     45           1      False    318      318
# 1       80     60           1      False    405      405
# 2      100     80           1      False    525      525
# 3      120     80           1      False    625      625
# 4       50     65           1      False    309      309

# %%
#alterar o local do Total no df
cols = list(df.columns)
df = df[cols[0:4] + [cols[-1]] + cols[4:12]]
df
# Out:
#        #                   Name   Type 1  Type 2  Total 2  HP  Attack  \
# 0      1              Bulbasaur    Grass  Poison      318  45      49
# 1      2                Ivysaur    Grass  Poison      405  60      62
# 2      3               Venusaur    Grass  Poison      525  80      82
# 3      3  VenusaurMega Venusaur    Grass  Poison      625  80     100
# 4      4             Charmander     Fire     NaN      309  39      52
# ..   ...                    ...      ...     ...      ...  ..     ...
# 795  719                Diancie     Rock   Fairy      600  50     100
# 796  719    DiancieMega Diancie     Rock   Fairy      700  50     160
# 797  720    HoopaHoopa Confined  Psychic   Ghost      600  80     110
# 798  720     HoopaHoopa Unbound  Psychic    Dark      680  80     160
# 799  721              Volcanion     Fire   Water      600  80     110
#
#      Defense  Sp. Atk  Sp. Def  Speed  Generation  Legendary
# 0         49       65       65     45           1      False
# ...

# %%
#salvar novo df SEM A PRIMEIRA COLUNA (INDEX)(0,1,2,3)
#df.to_csv('novodf.csv', index=False)

# %%
#tbm conseguimos fazer mais de um filter
df.loc[(df['Type 1'] == 'Grass') & (df['Type 2'] == 'Poison') & (df['HP'] > 70)]
# Out:
#        #                   Name Type 1  Type 2  Total 2   HP  Attack  Defense  \
# 2      3               Venusaur  Grass  Poison      525   80      82       83
# 3      3  VenusaurMega Venusaur  Grass  Poison      625   80     100      123
# 50    45              Vileplume  Grass  Poison      490   75      80       85
# 77    71             Victreebel  Grass  Poison      490   80     105       65
# 652  591              Amoonguss  Grass  Poison      464  114      85       70
#
#      Sp. Atk  Sp. Def  Speed  Generation  Legendary
# 2        100      100     80           1      False
# 3        122      120     80           1      False
# 50       110       90     50           1      False
# 77       100       70     70           1      False
# 652       85       80     30           5      False

# %%
#COINTAINS contem uma palavra
df.loc[df['Name'].str.contains('Mega')]
# Out:
#        #                       Name    Type 1    Type 2  Total 2   HP  Attack  \
# 3      3      VenusaurMega Venusaur     Grass    Poison      625   80     100
# 7      6  CharizardMega Charizard X      Fire    Dragon      634   78     130
# 8      6  CharizardMega Charizard Y      Fire    Flying      634   78     104
# 12     9    BlastoiseMega Blastoise     Water       NaN      630   79     103
# 19    15      BeedrillMega Beedrill       Bug    Poison      495   65     150
# 23    18        PidgeotMega Pidgeot    Normal    Flying      579   83      80
# 71    65      AlakazamMega Alakazam   Psychic       NaN      590   55      50
# 87    80        SlowbroMega Slowbro     Water   Psychic      590   95      75
# 102   94          GengarMega Gengar     Ghost    Poison      600   60      65
# 124  115  KangaskhanMega Kangaskhan    Normal       NaN      590  105     125
# 137  127          PinsirMega Pinsir       Bug    Flying      600   65     155
# ...

# %%
#COINTAINS ~~~~~~~~~ REMOVE nomes que contem uma palavra
df.loc[~df['Name'].str.contains('Mega')]
# Out:
#        #                 Name   Type 1  Type 2  Total 2   HP  Attack  Defense  \
# 0      1            Bulbasaur    Grass  Poison      318   45      49       49
# 1      2              Ivysaur    Grass  Poison      405   60      62       63
# 2      3             Venusaur    Grass  Poison      525   80      82       83
# 4      4           Charmander     Fire     NaN      309   39      52       43
# 5      5           Charmeleon     Fire     NaN      405   58      64       58
# ..   ...                  ...      ...     ...      ...  ...     ...      ...
# 794  718     Zygarde50% Forme   Dragon  Ground      600  108     100      121
# 795  719              Diancie     Rock   Fairy      600   50     100      150
# 797  720  HoopaHoopa Confined  Psychic   Ghost      600   80     110       60
# 798  720   HoopaHoopa Unbound  Psychic    Dark      680   80     160       60
# 799  721            Volcanion     Fire   Water      600   80     110      120
#
# ...

# %%
#df.loc[df['Type 1'].str.contains('Fire|Grass')]

#Para poder ignorar o capslock IMPORTE RE  -> FLAGS=RE.I
import re
df.loc[df['Type 1'].str.contains('FIRE|grass', flags=re.I)]
# Out:
#        #                   Name Type 1  Type 2  Total 2   HP  Attack  Defense  \
# 0      1              Bulbasaur  Grass  Poison      318   45      49       49
# 1      2                Ivysaur  Grass  Poison      405   60      62       63
# 2      3               Venusaur  Grass  Poison      525   80      82       83
# 3      3  VenusaurMega Venusaur  Grass  Poison      625   80     100      123
# 4      4             Charmander   Fire     NaN      309   39      52       43
# ..   ...                    ...    ...     ...      ...  ...     ...      ...
# 735  667                 Litleo   Fire  Normal      369   62      50       58
# 736  668                 Pyroar   Fire  Normal      507   86      68       72
# 740  672                 Skiddo  Grass     NaN      350   66      65       48
# 741  673                 Gogoat  Grass     NaN      531  123     100       62
# 799  721              Volcanion   Fire   Water      600   80     110      120
#
# ...

# %%
#               COMEÇA COM 'X[letra(s) em seguida]  Caso coloque o "*" no final ira aparecer os que possuem 0 ou mais das letras
df.loc[df['Name'].str.contains('pi[a-z]*', flags=re.I)]
# Out:
#        #                     Name    Type 1    Type 2  Total 2   HP  Attack  \
# 13    10                 Caterpie       Bug       NaN      195   45      30
# 20    16                   Pidgey    Normal    Flying      251   40      45
# 21    17                Pidgeotto    Normal    Flying      349   63      60
# 22    18                  Pidgeot    Normal    Flying      479   83      80
# 23    18      PidgeotMega Pidgeot    Normal    Flying      579   83      80
# 30    25                  Pikachu  Electric       NaN      320   35      55
# 42    37                   Vulpix      Fire       NaN      299   38      41
# 76    70               Weepinbell     Grass    Poison      390   65      90
# 84    78                 Rapidash      Fire       NaN      500   65     100
# 136  127                   Pinsir       Bug       NaN      500   65     125
# 137  127        PinsirMega Pinsir       Bug    Flying      600   65     155
# ...

# %%
#sem o *
df.loc[df['Name'].str.contains('pi[k]', flags=re.I)]
# Out:
#      #     Name    Type 1 Type 2  Total 2  HP  Attack  Defense  Sp. Atk  \
# 30  25  Pikachu  Electric    NaN      320  35      55       40       50
#
#     Sp. Def  Speed  Generation  Legendary
# 30       50     90           1      False

# %%
#para começar com as letras, COLOCAR-> ^
df.loc[df['Name'].str.contains('^pi[a-z]*', flags=re.I)]
# Out:
#        #                 Name    Type 1    Type 2  Total 2   HP  Attack  \
# 20    16               Pidgey    Normal    Flying      251   40      45
# 21    17            Pidgeotto    Normal    Flying      349   63      60
# 22    18              Pidgeot    Normal    Flying      479   83      80
# 23    18  PidgeotMega Pidgeot    Normal    Flying      579   83      80
# 30    25              Pikachu  Electric       NaN      320   35      55
# 136  127               Pinsir       Bug       NaN      500   65     125
# 137  127    PinsirMega Pinsir       Bug    Flying      600   65     155
# 186  172                Pichu  Electric       NaN      205   20      40
# 219  204               Pineco       Bug       NaN      290   50      65
# 239  221            Piloswine       Ice    Ground      450  100     100
# 438  393               Piplup     Water       NaN      314   53      51
# 558  499              Pignite      Fire  Fighting      418   90      93
# ...

# %%
#ALTERAR O NOME DOS DADOS INSERIDOS -> EX: TROCAR FIRE POR FOGO
df.loc[df['Type 1'] == 'Fire', 'Type 1'] = 'Fogo'
df
# Out:
# /usr/local/lib/python3.7/dist-packages/pandas/core/indexing.py:1817: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self._setitem_single_column(loc, value, pi)
#        #                   Name   Type 1  Type 2  Total 2  HP  Attack  \
# 0      1              Bulbasaur    Grass  Poison      318  45      49
# 1      2                Ivysaur    Grass  Poison      405  60      62
# 2      3               Venusaur    Grass  Poison      525  80      82
# 3      3  VenusaurMega Venusaur    Grass  Poison      625  80     100
# 4      4             Charmander     Fogo     NaN      309  39      52
# ..   ...                    ...      ...     ...      ...  ..     ...
# 795  719                Diancie     Rock   Fairy      600  50     100
# ...

# %%
#alterar +d 1 dado - condicao - primeiro     segundo           valor primeiro          valor segundo
df.loc[df['Total 2'] > 500, ['Legendary', 'Generation']] = ['Muito Forte LENDARIO', 'Geração Forte']
df
# Out:
# /usr/local/lib/python3.7/dist-packages/pandas/core/indexing.py:1797: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self._setitem_single_column(loc, v, pi)
#        #                   Name   Type 1  Type 2  Total 2  HP  Attack  \
# 0      1              Bulbasaur    Grass  Poison      318  45      49
# 1      2                Ivysaur    Grass  Poison      405  60      62
# 2      3               Venusaur    Grass  Poison      525  80      82
# 3      3  VenusaurMega Venusaur    Grass  Poison      625  80     100
# 4      4             Charmander     Fogo     NaN      309  39      52
# ..   ...                    ...      ...     ...      ...  ..     ...
# 795  719                Diancie     Rock   Fairy      600  50     100
# ...

# %%
#nometotal = ['Type 1', 'Total 2']
#mediatipo = df.filter(items=nometotal)

#Qual tipo de pokemon  tem a media de (ex: ataque)     MAIOR(do maior ao menor)
df.groupby('Type 1').mean().sort_values('Attack', ascending=False)
# Out:
#                    #     Total 2         HP      Attack     Defense  \
# Type 1
# Dragon    474.375000  550.531250  83.312500  112.125000   86.375000
# Fighting  363.851852  416.444444  69.851852   96.777778   65.925926
# Ground    356.281250  437.500000  73.781250   95.750000   84.843750
# Rock      392.727273  453.750000  65.363636   92.863636  100.795455
# Steel     442.851852  487.703704  65.222222   92.703704  126.370370
# Dark      461.354839  445.741935  66.806452   88.387097   70.225806
# Fogo      327.403846  458.076923  69.903846   84.769231   67.769231
# Flying    677.750000  485.000000  70.750000   78.750000   66.250000
# Poison    251.785714  399.142857  67.250000   74.678571   68.821429
# Water     303.089286  430.455357  72.062500   74.151786   72.946429
# Ghost     486.500000  439.562500  64.437500   73.781250   81.187500
# Normal    319.173469  401.683673  77.275510   73.469388   59.846939
# Grass     344.871429  421.142857  67.271429   73.214286   70.800000
# ...

# %%
#quantidade de cada tipo de pokemon
df['count']=1
df.groupby('Type 1').count()['count'].sort_values(ascending=False)
# Out:
# Type 1
# Water       112
# Normal       98
# Grass        70
# Bug          69
# Psychic      57
# Fogo         52
# Electric     44
# Rock         44
# Ghost        32
# Ground       32
# Dragon       32
# Dark         31
# Poison       28
# Fighting     27
# Steel        27
# Ice          24
# Fairy        17
# Flying        4
# Name: count, dtype: int64

# %%
#quantidade de cada tipo2 de pokemon dentro dos principais tipos
#duas condições

df.groupby(['Type 1', 'Type 2']).count()['count'].sort_values(ascending=False)
# Out:
# Type 1    Type 2
# Normal    Flying    24
# Grass     Poison    15
# Bug       Flying    14
#           Poison    12
# Ghost     Grass     10
#                     ..
# Fogo      Rock       1
#           Dragon     1
# Ice       Ghost      1
# Fighting  Flying     1
# Water     Steel      1
# Name: count, Length: 136, dtype: int64

# %% [markdown]
# #Filmes

# %%
import pandas as pd
filmes = pd.read_csv('/content/drive/MyDrive/Dados python/titles.csv')
creditsdf = pd.read_csv('/content/drive/MyDrive/Dados python/credits.csv')

# %%
filmes.head()
# Out:
#          id                                title   type  \
# 0  ts300399  Five Came Back: The Reference Films   SHOW
# 1   tm84618                          Taxi Driver  MOVIE
# 2  tm127384      Monty Python and the Holy Grail  MOVIE
# 3   tm70993                        Life of Brian  MOVIE
# 4  tm190788                         The Exorcist  MOVIE
#
#                                          description  release_year  \
# 0  This collection includes 12 World War II-era p...          1945
# 1  A mentally unstable Vietnam War veteran works ...          1976
# 2  King Arthur, accompanied by his squire, recrui...          1975
# 3  Brian Cohen is an average young Jewish man, bu...          1979
# 4  12-year-old Regan MacNeil begins to adapt an e...          1973
#
#   age_certification  runtime                 genres production_countries  \
# 0             TV-MA       48      ['documentation']               ['US']
# 1                 R      113     ['crime', 'drama']               ['US']
# ...

# %%
filmes['type'].value_counts().plot(kind='bar')

# %%
filmes.loc[filmes.genres.isin(["['comedy']"])].head(3)
# Out:
#          id                             title   type  \
# 3   tm70993                     Life of Brian  MOVIE
# 29  ts45948  Monty Python's Fliegender Zirkus   SHOW
# 32  tm97793                Lock Your Girls In  MOVIE
#
#                                           description  release_year  \
# 3   Brian Cohen is an average young Jewish man, bu...          1979
# 29  Monty Python's Fliegender Zirkus consisted of ...          1972
# 32  Dr. Raafat faces challenges and difficulties i...          1980
#
#    age_certification  runtime      genres production_countries  seasons  \
# 3                  R       94  ['comedy']               ['GB']      NaN
# 29             TV-MA       43  ['comedy']                   []      1.0
# 32               NaN      230  ['comedy']               ['EG']      NaN
#
#       imdb_id  imdb_score  imdb_votes  tmdb_popularity  tmdb_score
# 3   tt0079470         8.0    392419.0           17.505         7.8
# ...
